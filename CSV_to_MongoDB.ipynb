# %%
# Modules to run code
import csv
import pymongo
import pandas as pd

# %%
# Import .csv files from Resources folder
birds_data = pd.read_csv('./data/Endangered_Birds.csv')
plants_data = pd.read_csv('./data/Endangered_Plants.csv')
population_data = pd.read_csv('./data/cleanedPopulationData.csv')

# %%
# Establish connection to local host 27017
conn = 'mongodb://localhost:27017'

# Connect to MongoClient
client = pymongo.MongoClient(conn)

# Begin by dropping any previous version of the MongoDB instance.
client.drop_database('Endangered_Birds')

# %%
# Create database by naming db here
db = client.Endangered_Species

# Create collection by naming collection here
bird_collection = db.birds
plants_collection = db.plants
population_collection = db.population

# %%
# Use ".to_dict('records')"in combination with .csv variable to create list of dictionaries data set
birds_data.reset_index(inplace=True)
plants_data.reset_index(inplace=True)
population_data.reset_index(inplace=True)

birds_data_dict = birds_data.to_dict('records')
plants_data_dict = plants_data.to_dict('records')
population_data_dict = population_data.to_dict('records')

# %%
# Insert data from the 'data_dict' variable into the collection using 'collection' variable
bird_collection.insert_many(birds_data_dict)
plants_collection.insert_many(plants_data_dict)
population_collection.insert_many(population_data_dict)

# %%
# CODE TO PRINT OUT CONTENTS OF THE DATABASE

# Store dataset now contained in the collection using the collection's name
query = db.birds.find()

# Use a for loop to confirm data is now located in the database
for x in query:
    print(x)
# Out:
# {'_id': ObjectId('5f978e9410d06e08d2b829d0'), 'index': 0, 'State': 'WI', 'Lat': 44.5, 'Long': -89.5, 'Organism Type': 'Bird', 'Species Name': "Kirtland's Warbler", 'Federal Status': 'Endangered', 'Unit Name': 'St. Croix WMD'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d1'), 'index': 1, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Attwater Prairie Chicken NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d2'), 'index': 2, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d3'), 'index': 3, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d4'), 'index': 4, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d5'), 'index': 5, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d6'), 'index': 6, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d7'), 'index': 7, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d8'), 'index': 8, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829d9'), 'index': 9, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829da'), 'index': 10, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829db'), 'index': 11, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous Pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829dc'), 'index': 12, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829dd'), 'index': 13, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Eskimo Curlew', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829de'), 'index': 14, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829df'), 'index': 15, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e0'), 'index': 16, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e1'), 'index': 17, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Buffalo Lake NWR (TX)'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e2'), 'index': 18, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e3'), 'index': 19, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e4'), 'index': 20, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e5'), 'index': 21, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e6'), 'index': 22, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Brazoria NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e7'), 'index': 23, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e8'), 'index': 24, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Anahuac NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829e9'), 'index': 25, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829ea'), 'index': 26, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829eb'), 'index': 27, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Texas Point NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829ec'), 'index': 28, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829ed'), 'index': 29, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'McFaddin NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829ee'), 'index': 30, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829ef'), 'index': 31, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f0'), 'index': 32, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f1'), 'index': 33, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Trinity River NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f2'), 'index': 34, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f3'), 'index': 35, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Sand Lake NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f4'), 'index': 36, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Sand Lake WMD'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f5'), 'index': 37, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lacreek NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f6'), 'index': 38, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sand Lake WMD'}
# {'_id': ObjectId('5f978e9410d06e08d2b829f7'), 'index': 39, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sand Lake NWR'}
# {'_id': ObjectId('5f978e9410d06e08d2b829