# %%
# Modules to run code
import csv
import pymongo
import pandas as pd

# %%
# Import .csv files from Resources folder
birds_data = pd.read_csv('./Endangered_Birds.csv')
plants_data = pd.read_csv('./Endangered_Plants.csv')

# %%
# Establish connection to local host 27017
conn = 'mongodb://localhost:27017'

# Connect to MongoClient
client = pymongo.MongoClient(conn)

# Begin by dropping any previous version of the MongoDB instance.
client.drop_database('Endangered_Birds')

# %%
# Create database by naming db here
db = client.Endangered_Species

# Create collection by naming collection here
bird_collection = db.birds
plants_collection = db.plants

# %%
# Use ".to_dict('records')"in combination with .csv variable to create list of dictionaries data set
birds_data.reset_index(inplace=True)
plants_data.reset_index(inplace=True)

birds_data_dict = birds_data.to_dict('records')
plants_data_dict = plants_data.to_dict('records')

# %%
# Insert data from the 'data_dict' variable into the collection using 'collection' variable
bird_collection.insert_many(birds_data_dict)
plants_collection.insert_many(plants_data_dict)

# %%
# CODE TO PRINT OUT CONTENTS OF THE DATABASE

# Store dataset now contained in the collection using the collection's name
query = db.birds.find()

# Use a for loop to confirm data is now located in the database
for x in query:
    print(x)
# Out:
# {'_id': ObjectId('5f94fb8910d06e08d2b81bcc'), 'index': 0, 'State': 'WI', 'Lat': 44.5, 'Long': -89.5, 'Organism Type': 'Bird', 'Species Name': "Kirtland's Warbler", 'Federal Status': 'Endangered', 'Unit Name': 'St. Croix WMD'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bcd'), 'index': 1, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Attwater Prairie Chicken NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bce'), 'index': 2, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bcf'), 'index': 3, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd0'), 'index': 4, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd1'), 'index': 5, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd2'), 'index': 6, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd3'), 'index': 7, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd4'), 'index': 8, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd5'), 'index': 9, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd6'), 'index': 10, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd7'), 'index': 11, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous Pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd8'), 'index': 12, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bd9'), 'index': 13, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Eskimo Curlew', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bda'), 'index': 14, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bdb'), 'index': 15, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bdc'), 'index': 16, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bdd'), 'index': 17, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Buffalo Lake NWR (TX)'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bde'), 'index': 18, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bdf'), 'index': 19, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be0'), 'index': 20, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be1'), 'index': 21, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be2'), 'index': 22, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Brazoria NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be3'), 'index': 23, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be4'), 'index': 24, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Anahuac NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be5'), 'index': 25, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be6'), 'index': 26, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be7'), 'index': 27, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Texas Point NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be8'), 'index': 28, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81be9'), 'index': 29, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'McFaddin NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bea'), 'index': 30, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81beb'), 'index': 31, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bec'), 'index': 32, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bed'), 'index': 33, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Trinity River NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bee'), 'index': 34, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bef'), 'index': 35, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Sand Lake NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf0'), 'index': 36, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Sand Lake WMD'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf1'), 'index': 37, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lacreek NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf2'), 'index': 38, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sand Lake WMD'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf3'), 'index': 39, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sand Lake NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf4'), 'index': 40, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Andes WMD'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf5'), 'index': 41, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Andes NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf6'), 'index': 42, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sachuest Point NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf7'), 'index': 43, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Trustom Pond NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81bf8'), 'index': 44, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Ninigret NWR'}
# {'_id': ObjectId('5f94fb8910d06e08d2b81