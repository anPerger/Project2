# %%
# Modules to run code
import csv
import pymongo
import pandas as pd

# %%
# Import .csv files from Resources folder
birds_data = pd.read_csv('./Endangered_Birds.csv')
plants_data = pd.read_csv('./Endangered_Plants.csv')
population_data = pd.read_csv('./cleanedPopulationData.csv')

# %%
# Establish connection to local host 27017
conn = 'mongodb://localhost:27017'

# Connect to MongoClient
client = pymongo.MongoClient(conn)

# Begin by dropping any previous version of the MongoDB instance.
client.drop_database('Endangered_Birds')

# %%
# Create database by naming db here
db = client.Endangered_Species

# Create collection by naming collection here
bird_collection = db.birds
plants_collection = db.plants
population_collection = db.population

# %%
# Use ".to_dict('records')"in combination with .csv variable to create list of dictionaries data set
birds_data.reset_index(inplace=True)
plants_data.reset_index(inplace=True)
population_data.reset_index(inplace=True)

birds_data_dict = birds_data.to_dict('records')
plants_data_dict = plants_data.to_dict('records')
population_data_dict = population_data.to_dict('records')

# %%
# Insert data from the 'data_dict' variable into the collection using 'collection' variable
bird_collection.insert_many(birds_data_dict)
plants_collection.insert_many(plants_data_dict)
population_collection.insert_many(population_data_dict)

# %%
# CODE TO PRINT OUT CONTENTS OF THE DATABASE

# Store dataset now contained in the collection using the collection's name
query = db.birds.find()

# Use a for loop to confirm data is now located in the database
for x in query:
    print(x)
# Out:
# {'_id': ObjectId('5f9653e210d06e08d2b82582'), 'index': 0, 'State': 'WI', 'Lat': 44.5, 'Long': -89.5, 'Organism Type': 'Bird', 'Species Name': "Kirtland's Warbler", 'Federal Status': 'Endangered', 'Unit Name': 'St. Croix WMD'}
# {'_id': ObjectId('5f9653e210d06e08d2b82583'), 'index': 1, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Attwater Prairie Chicken NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82584'), 'index': 2, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82585'), 'index': 3, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82586'), 'index': 4, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82587'), 'index': 5, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82588'), 'index': 6, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82589'), 'index': 7, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8258a'), 'index': 8, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8258b'), 'index': 9, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8258c'), 'index': 10, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8258d'), 'index': 11, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous Pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8258e'), 'index': 12, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8258f'), 'index': 13, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Eskimo Curlew', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82590'), 'index': 14, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82591'), 'index': 15, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82592'), 'index': 16, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82593'), 'index': 17, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Buffalo Lake NWR (TX)'}
# {'_id': ObjectId('5f9653e210d06e08d2b82594'), 'index': 18, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82595'), 'index': 19, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82596'), 'index': 20, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82597'), 'index': 21, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82598'), 'index': 22, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Brazoria NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82599'), 'index': 23, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8259a'), 'index': 24, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Anahuac NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8259b'), 'index': 25, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': '
WR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8263b'), 'index': 185, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Yukon Delta NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8263c'), 'index': 186, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Chickasaw NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8263d'), 'index': 187, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Cross Creeks NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8263e'), 'index': 188, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Hatchie NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b8263f'), 'index': 189, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Isom NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82640'), 'index': 190, 'State': 'VA', 'Lat': 37.926868, 'Long': -78.024902, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Back Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82641'), 'index': 191, 'State': 'VA', 'Lat': 37.926868, 'Long': -78.024902, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Fisherman Island NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82642'), 'index': 192, 'State': 'NJ', 'Lat': 39.833851, 'Long': -74.871826, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Edwin B. Forsythe NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82643'), 'index': 193, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Eskimo Curlew', 'Federal Status': 'Endangered', 'Unit Name': 'North Dakota WMA'}
# {'_id': ObjectId('5f9653e210d06e08d2b82644'), 'index': 194, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Interior Least Tern', 'Federal Status': 'Endangered', 'Unit Name': 'North Dakota WMA'}
# {'_id': ObjectId('5f9653e210d06e08d2b82645'), 'index': 195, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Nettie NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82646'), 'index': 196, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Long Lake NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82647'), 'index': 197, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Audubon WMD'}
# {'_id': ObjectId('5f9653e210d06e08d2b82648'), 'index': 198, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Audubon NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b82649'), 'index': 199, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Mountain Plover', 'Federal Status': 'Proposed', 'Unit Name': 'North Dakota WMA'}
# {'_id': ObjectId('5f9653e210d06e08d2b8264a'), 'index': 200, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Buffalo Lake NWR (ND)'}
# {'_id': ObjectId('5f9653e210d06e08d2b8264b'), 'index': 201, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Audubon WMD'}
# {'_id': ObjectId('5f9653e210d06e08d2b8264c'), 'index': 202, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Cottonwood Lake NWR'}
# ...
# {'_id': ObjectId('5f9653e210d06e08d2b826c1'), 'index': 319, 'State': 'MA', 'Lat': 42.407211, 'Long': -71.382439, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Mashpee NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c2'), 'index': 320, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c3'), 'index': 321, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Guadalupe-Nipomo Dunes NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c4'), 'index': 322, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c5'), 'index': 323, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c6'), 'index': 324, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Salinas River NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c7'), 'index': 325, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Sonny Bono Salton Sea NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c8'), 'index': 326, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826c9'), 'index': 327, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ca'), 'index': 328, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826cb'), 'index': 329, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'California Condor', 'Federal Status': 'Endangered', 'Unit Name': 'Bitter Creek NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826cc'), 'index': 330, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'California Condor', 'Federal Status': 'Endangered', 'Unit Name': 'Blue Ridge NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826cd'), 'index': 331, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'California Condor', 'Federal Status': 'Endangered', 'Unit Name': 'Hopper Mountain NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ce'), 'index': 332, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, California', 'Federal Status': 'Endangered', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826cf'), 'index': 333, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, California', 'Federal Status': 'Endangered', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d0'), 'index': 334, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, California', 'Federal Status': 'Endangered', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d1'), 'index': 335, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Light-footed', 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d2'), 'index': 336, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Light-footed', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d3'), 'index': 337, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Light-footed', 'Federal Status': 'Endangered', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d4'), 'index': 338, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Yuma', 'Federal Status': 'Endangered', 'Unit Name': 'Sonny Bono Salton Sea NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d5'), 'index': 339, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Coastal California Gnatcatcher', 'Federal Status': 'Threatened', 'Unit Name': 'San Diego NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d6'), 'index': 340, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d7'), 'index': 341, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': "Least Bell's Vireo", 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d8'), 'index': 342, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': "Least Bell's Vireo", 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826d9'), 'index': 343, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': "Least Bell's Vireo", 'Federal Status': 'Endangered', 'Unit Name': 'San Diego NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826da'), 'index': 344, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Guadalupe-Nipomo Dunes NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826db'), 'index': 345, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826dc'), 'index': 346, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826dd'), 'index': 347, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826de'), 'index': 348, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826df'), 'index': 349, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e0'), 'index': 350, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Southwestern Willow Flycatcher', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e1'), 'index': 351, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Humboldt Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e2'), 'index': 352, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e3'), 'index': 353, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e4'), 'index': 354, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Guadalupe-Nipomo Dunes NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e5'), 'index': 355, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e6'), 'index': 356, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e7'), 'index': 357, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e8'), 'index': 358, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826e9'), 'index': 359, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Salinas River NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ea'), 'index': 360, 'State': 'ID', 'Lat': 44.068203, 'Long': -114.742043, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Bear Lake NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826eb'), 'index': 361, 'State': 'ID', 'Lat': 44.068203, 'Long': -114.742043, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Grays Lake NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ec'), 'index': 362, 'State': 'WY', 'Lat': 43.07597, 'Long': -107.290283, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'National Elk Refuge'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ed'), 'index': 363, 'State': 'WY', 'Lat': 43.07597, 'Long': -107.290283, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Cokeville Meadows NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ee'), 'index': 364, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Currituck NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ef'), 'index': 365, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Pea Island NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f0'), 'index': 366, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Cedar Island NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f1'), 'index': 367, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Pee Dee NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f2'), 'index': 368, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Alligator River NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f3'), 'index': 369, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Big Branch Marsh NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f4'), 'index': 370, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Bayou Sauvage NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f5'), 'index': 371, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Delta NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f6'), 'index': 372, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Shell Keys NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f7'), 'index': 373, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Breton NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f8'), 'index': 374, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Bayou Sauvage NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826f9'), 'index': 375, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Breton NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826fa'), 'index': 376, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Big Branch Marsh NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826fb'), 'index': 377, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Delta NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826fc'), 'index': 378, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Shell Keys NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826fd'), 'index': 379, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Upper Ouachita NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826fe'), 'index': 380, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Big Branch Marsh NWR'}
# {'_id': ObjectId('5f9653e210d06e08d2b826ff'), 'index': 381, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': "D'Arbonne NWR"}
